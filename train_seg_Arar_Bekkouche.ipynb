# %% [markdown]
# Préparation du dataset

# %%
# 1. Installation
# !pip install --upgrade pip setuptools wheel
# On installe YOLO
# !pip install ultralytics==8.3.0
# !pip install roboflow --prefer-binary

from ultralytics import YOLO
from roboflow import Roboflow

# ZONE ROBOFLOW

# !!pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Z8X2F5eXsmjqmVkX02t6")
project = rf.workspace("ia-embarque-fcjts").project("trackroad")
version = project.version(10)
dataset = version.download("yolov8")

# ==============================================================================

print("--> Téléchargement terminé. Lancement de l'entraînement...")

# 2. Chargement du modèle de base
model = YOLO("yolov8n-seg.pt")

# 3. ENTRAINEMENT
results = model.train(
    overlap_mask = True,
    data=f"{dataset.location}/data.yaml",

    epochs=100,                            # 100 Epoques
    imgsz=128,                             # Taille 128x128
    patience=20,                           # Arrêt auto
    batch=16,
    device=0,
    name='mon_modele_route'
)
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# --> Téléchargement terminé. Lancement de l'entraînement...
# New https://pypi.org/project/ultralytics/8.4.11 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.0 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# Entraînement du modèle YOLOv8

# %% [markdown]
# Affichage des résultats avec TensorFlow

# %%
# !yolo settings | head -n 50
# !find /content/runs -maxdepth 4 -type f \( -name "events.out.tfevents.*" -o -name "results.csv" \) | head -n 50
# %load_ext tensorboard
# %tensorboard --logdir /content/runs/segment/train10
